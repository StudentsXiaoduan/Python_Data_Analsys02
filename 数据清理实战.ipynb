# %% [markdown]
# 读取数据

# %%
import pandas as pd

# %%
import numpy as np

# %%
df01 = pd.read_excel(r"D:\Users\Desktop\旅游景点.xlsx")
df01.head()
# Out:
#    Unnamed: 0  城市        名称   星级   评分     价格     销量       省/市/区  \
# 0           0  上海   上海迪士尼乐园  NaN    0    325  19459  上海·上海·浦东新区
# 1           1  上海  上海海昌海洋公园  4 A    0  276.5  19406  上海·上海·浦东新区
# 2           2  上海   上海野生动物园  5 A  3.6    116   6764  上海·上海·浦东新区
# 3           3  上海      东方绿舟  4 A  3.5     40   5353   上海·上海·青浦区
# 4           4  上海      东方明珠  5 A  3.8     54   3966  上海·上海·浦东新区
#
#                      坐标                   简介   是否免费                      具体地址
# 0  121.667917,31.149712         每个女孩都有一场迪士尼梦  False  上海市浦东新区川沙镇黄赵路310号上海迪士尼乐园
# 1  121.915647,30.917713   看珍稀海洋生物 | 玩超刺激娱乐项目  False         上海市浦东新区南汇城银飞路166号
# 2  121.728112,31.059636  全球动物聚集地 | 零距离和动物做朋友  False           上海市浦东新区南六公路178号
# 3  121.015977,31.107866     全国首屈一指的青少年校外教育营地  False          上海市青浦区沪青平公路6888号
# 4   121.50626,31.245369       感受云端漫步，品味老上海风情  False             上海市浦东新区世纪大道1号

# %%
df01 = df01.set_index("Unnamed: 0")
df01.head()
# Out:
#             城市        名称   星级   评分     价格     销量       省/市/区  \
# Unnamed: 0
# 0           上海   上海迪士尼乐园  NaN    0    325  19459  上海·上海·浦东新区
# 1           上海  上海海昌海洋公园  4 A    0  276.5  19406  上海·上海·浦东新区
# 2           上海   上海野生动物园  5 A  3.6    116   6764  上海·上海·浦东新区
# 3           上海      东方绿舟  4 A  3.5     40   5353   上海·上海·青浦区
# 4           上海      东方明珠  5 A  3.8     54   3966  上海·上海·浦东新区
#
#                               坐标                   简介   是否免费  \
# Unnamed: 0
# 0           121.667917,31.149712         每个女孩都有一场迪士尼梦  False
# 1           121.915647,30.917713   看珍稀海洋生物 | 玩超刺激娱乐项目  False
# 2           121.728112,31.059636  全球动物聚集地 | 零距离和动物做朋友  False
# 3           121.015977,31.107866     全国首屈一指的青少年校外教育营地  False
# 4            121.50626,31.245369       感受云端漫步，品味老上海风情  False
#
#                                 具体地址
# Unnamed: 0
# 0           上海市浦东新区川沙镇黄赵路310号上海迪士尼乐园
# 1                  上海市浦东新区南汇城银飞路166号
# 2                    上海市浦东新区南六公路178号
# 3                   上海市青浦区沪青平公路6888号
# ...

# %% [markdown]
# 评估数据（主要评估数据的整齐度和干净度。结构性问题：整洁数据是：每列是一个变量，每行是一个观察值，每个单元格是一个值，对应整齐度。内容性问题：丢失数据、重复数据、无效数据。对应干净度）

# %% [markdown]
# 评估数据整齐度（结构性问题）

# %%
df01.sample(10)
# Out:
#              城市              名称   星级   评分     价格   销量          省/市/区  \
# Unnamed: 0
# 1933         西藏          奇林峡风景区  NaN    0    180   71    西藏·日喀则·日喀则市
# 464          四川             石象湖  4 A  3.5     39  252      四川·成都·蒲江县
# 181         内蒙古       海拉尔国家森林公园   3A  3.6      3   54  内蒙古·呼伦贝尔·海拉尔区
# 1786         甘肃             锁阳城  NaN  3.5     45    4      甘肃·酒泉·瓜州县
# 1824         福建             上清溪  NaN  4.3    125   52      福建·三明·泰宁县
# 1844         福建       福州欧乐堡海洋世界  NaN    0  200.5  318      福建·福州·永泰县
# 58           上海  BUS TOUR 上海观光游  NaN    0     85   64      上海·上海·黄浦区
# 1669         澳门         新濠影汇摩天轮  NaN    0     49  126     澳门·澳门·新濠影汇
# 1903         西藏           南迦巴瓦峰  NaN    4    150   22      西藏·林芝·林芝县
# 2254         青海       青藏高原自然博物馆  NaN    0     45   20      青海·西宁·城北区
#
#                               坐标                   简介   是否免费  \
# Unnamed: 0
# 1933         88.110749,28.153311                  NaN  False
# ...

# %% [markdown]
# 整齐度上看:每列是一个变量，每行是一个观察值，每个单元格是一个值，不存在结构性问题

# %% [markdown]
# 评估数据干净度

# %%
df01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2443 entries, 0 to 2442
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   城市      2443 non-null   object
#  1   名称      2443 non-null   object
#  2   星级      913 non-null    object
#  3   评分      2443 non-null   object
#  4   价格      2443 non-null   object
#  5   销量      2443 non-null   object
#  6   省/市/区   2443 non-null   object
#  7   坐标      2443 non-null   object
#  8   简介      2402 non-null   object
#  9   是否免费    2443 non-null   bool
#  10  具体地址    2440 non-null   object
# dtypes: bool(1), object(10)
# memory usage: 212.3+ KB

# %% [markdown]
# 星级、 简介   存在缺失值，评分、价格、销量数据类型不是字符串

# %% [markdown]
# 评估缺失数据

# %%
df01[df01["星级"].isnull()]
# Out:
#              城市             名称   星级   评分    价格     销量            省/市/区  \
# Unnamed: 0
# 0            上海        上海迪士尼乐园  NaN    0   325  19459       上海·上海·浦东新区
# 5            上海        上海自然博物馆  NaN  3.5  32.4   3237        上海·上海·静安区
# 10           上海          辰山植物园  NaN    0    60   1654  上海·上海·佘山国家旅游度假区
# 11           上海   黄浦江游览（十六铺码头）  NaN    0    90   1576        上海·上海·黄浦区
# 12           上海  上海中心大厦上海之巅观光厅  NaN    0   153   1212       上海·上海·浦东新区
# ...         ...            ...  ...  ...   ...    ...              ...
# 2436        黑龙江       哈尔滨沐欣源会馆  NaN    0  17.9     94      黑龙江·哈尔滨·道里区
# 2438        黑龙江        中央大街步行街  NaN  4.2   258     84      黑龙江·哈尔滨·道里区
# 2440        黑龙江       哈尔滨世界欢乐城  NaN    0    63     40      黑龙江·哈尔滨·松北区
# 2441        黑龙江            胭脂沟  NaN    4   298     67     黑龙江·大兴安岭·漠河县
# 2442        黑龙江        漠河火灾纪念馆  NaN  4.5   400     68     黑龙江·大兴安岭·漠河县
#
#                                          坐标  \
# Unnamed: 0
# ...

# %% [markdown]
# 寻找“星级”值缺失，并且“简介”也缺失的观察值

# %%
df01[(df01["星级"].isnull())&(df01["简介"].isnull())]
# Out:
#              城市                   名称   星级 评分      价格   销量  \
# Unnamed: 0
# 40           上海  上海世茂精灵之城主题乐园（蓝精灵乐园）  NaN  0  146.69  134
# 58           上海       BUS TOUR 上海观光游  NaN  0      85   64
# 154         内蒙古              莫尼山非遗小镇  NaN  0      48   16
# 199         内蒙古      莫力庙世源温泉度假疗养康复中心  NaN  0      88   82
# 277          北京      慕田峪长城岁月沉浸式光影体验馆  NaN  0      40  104
# 321          台湾           林本源园邸和林家花园  NaN  0       0    0
# 323          台湾                 台北戏棚  NaN  0       0    0
# 330          台湾             台北国际会议中心  NaN  0       0    0
# 341          台湾             万里翡翠湾滑翔伞  NaN  0       0    0
# 383          吉林         长春莲花岛影视休闲文化园  NaN  0      28    6
# 387          吉林                大西洋汤泉  NaN  0      19    4
# 407          吉林                 岚溪洗浴  NaN  0    17.9   66
# 411          吉林       智慧私人影院(人民大剧院店)  NaN  0      98   30
# 412          吉林          洺池宝石浴(抚松路店)  NaN  0    13.9   92
# 492          四川               大千欢乐世界  NaN  0     120  178
# ...

# %% [markdown]
# 星级 和 简介 同时缺失 值无参考，后续当删除这些值

# %% [markdown]
# 评估重复数据

# %%
df01["坐标"].drop_duplicates()
# Out:
# Unnamed: 0
# 0                  121.667917,31.149712
# 1                  121.915647,30.917713
# 2                  121.728112,31.059636
# 3                  121.015977,31.107866
# 4                   121.50626,31.245369
#                      ...
# 2438               126.626875,45.774125
# 2439               128.502737,46.820018
# 2440               126.544242,45.885823
# 2441               122.172361,53.279025
# 2442    122.53552358063,52.966979944456
# Name: 坐标, Length: 2390, dtype: object

# %% [markdown]
# 评估不一致数据

# %%
df01["城市"].value_counts()
# Out:
# 内蒙古    76
# 北京     75
# 山西     75
# 云南     75
# 河南     75
# 广西     75
# 江西     75
# 四川     75
# 福建     75
# 安徽     75
# 广东     75
# 天津     75
# 贵州     75
# 重庆     75
# 河北     75
# 山东     75
# 江苏     75
# 宁夏     75
# 甘肃     74
# 湖北     74
# 黑龙江    74
# 新疆     74
# 陕西     73
# 西藏     73
# 青海     73
# 海南     72
# 吉林     72
# 台湾     71
# 澳门     71
# 上海     60
# 辽宁     60
# 浙江     60
# 湖南     60
# 香港     51
# Name: 城市, dtype: int64

# %% [markdown]
# 评估无效和错误数据

# %%
df01.describe()
# Out:
#           城市     名称   星级    评分    价格    销量       省/市/区       坐标  \
# count   2443   2443  913  2443  2443  2443        2443     2443
# unique    34   2443    5    18   541   562        1185     2390
# top      内蒙古  郑州动物园  4 A     0     0     0  澳门·澳门·澳门半岛  0.0,0.0
# freq      76      1  543  1419   125   123          25       25
#
#                         简介   是否免费             具体地址
# count                 2402   2443             2440
# unique                2399      2             2386
# top     石奇，松秀，大气磅礴的“北国小黄山”  False  山西省忻州市五台县五台山风景区
# freq                     2   2381                7

# %% [markdown]
# 找出地址是以 河南省 开头的数据

# %%
df01[(df01["具体地址"].str[0] == "河")&(df01["具体地址"].str[1] == "南")&(df01["具体地址"].str[3] == "洛")]
# Out:
#             城市                   名称   星级   评分    价格    销量      省/市/区  \
# Unnamed: 0
# 1328        河南                 龙门石窟  5 A    5    90  4673  河南·洛阳·洛龙区
# 1329        河南                老君山景区  5 A  3.6    85  4005  河南·洛阳·栾川县
# 1330        河南                中国国花园  NaN  3.8    10  2250  河南·洛阳·老城区
# 1335        河南          隋唐洛阳城明堂天堂景区  NaN    0  88.4  1038  河南·洛阳·老城区
# 1337        河南                国家牡丹园  NaN  3.6    27   716  河南·洛阳·西工区
# 1341        河南             隋唐城遗址植物园  NaN    0    10   630  河南·洛阳·洛龙区
# 1351        河南                国际牡丹园  NaN    0    38   332      河南·洛阳
# 1352        河南                洛阳白马寺  4 A  4.4    99   320  河南·洛阳·洛龙区
# 1366        河南                  关林庙  4 A    4    40   150  河南·洛阳·洛龙区
# 1367        河南           周王城天子驾六博物馆   3A  3.7    25   150  河南·洛阳·西工区
# 1370        河南              洛阳龙门海洋馆  NaN    0  62.5   132  河南·洛阳·洛龙区
# 1378        河南                  鸡冠洞  5 A  3.6    75   110  河南·洛阳·栾川县
# ...

# %% [markdown]
# 数据清理

# %%
cleaned_data = df01.copy()
cleaned_data
# Out:
#              城市         名称   星级   评分     价格     销量         省/市/区  \
# Unnamed: 0
# 0            上海    上海迪士尼乐园  NaN    0    325  19459    上海·上海·浦东新区
# 1            上海   上海海昌海洋公园  4 A    0  276.5  19406    上海·上海·浦东新区
# 2            上海    上海野生动物园  5 A  3.6    116   6764    上海·上海·浦东新区
# 3            上海       东方绿舟  4 A  3.5     40   5353     上海·上海·青浦区
# 4            上海       东方明珠  5 A  3.8     54   3966    上海·上海·浦东新区
# ...         ...        ...  ...  ...    ...    ...           ...
# 2438        黑龙江    中央大街步行街  NaN  4.2    258     84   黑龙江·哈尔滨·道里区
# 2439        黑龙江  悬羊峰国家地质公园  4 A    0     35     67    黑龙江·伊春·铁力市
# 2440        黑龙江   哈尔滨世界欢乐城  NaN    0     63     40   黑龙江·哈尔滨·松北区
# 2441        黑龙江        胭脂沟  NaN    4    298     67  黑龙江·大兴安岭·漠河县
# 2442        黑龙江    漠河火灾纪念馆  NaN  4.5    400     68  黑龙江·大兴安岭·漠河县
#
#                                          坐标  \
# Unnamed: 0
# 0                      121.667917,31.149712
# 1                      121.915647,30.917713
# ...

# %% [markdown]
# 另外：将某一列数据变换成datatime类型   pd.to_datetime(df02["某一列"])

# %% [markdown]
# 评分、价格、销量数量类型不是字符串

# %%
df01["价格"]=df01["价格"].str.strip()

# %%
df01["价格"]=df01["价格"].str.strip("\n")

# %%
df01["价格"]=df01["价格"].str.strip("\"")

# %%
df01["价格"]=df01["价格"].str.strip("\"")

# %%
for st01 in df01["价格"]:
  
   
    st01 = [float(x) for x in st01]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-81-e55a74fbcfc8> in <module>()
#       2
#       3
# ----> 4     st01 = [float(x) for x in st01]
#
# TypeError: 'float' object is not iterable

# %% [markdown]
# 剪切string 用str.slice(0,-1)

# %% [markdown]
# 删除缺失值

# %%
df01["星级"].dropna()
# Out:
# Unnamed: 0
# 1       4 A
# 2       5 A
# 3       4 A
# 4       5 A
# 6        3A
#        ...
# 2416    5 A
# 2420    4 A
# 2423    4 A
# 2437    4 A
# 2439    4 A
# Name: 星级, Length: 913, dtype: object

# %% [markdown]
# 或者

# %%
df01.dropna(subset=["星级"],inplace=True)

# %%
df01["星级"].isnull().sum()
# Out:
# 0

# %% [markdown]
# 把城市中 河南 替换成河南省

# %%
df01["城市"]=df01["城市"].replace({"河南":"河南省"})

# %%
len(df01[df01["城市"]=="河南"])
# Out:
# 0

# %% [markdown]
#  删除 城市中 为河南省的行

# %%
df02 = df01[df01["城市"] != "河南省"]

# %%
sum(df02["城市"]=="河南省")
# Out:
# 0

# %% [markdown]
# 保存清理后的数据

# %%
df02.to_csv("cleaned_data003.csv",index=False)

# %%
pd.read_csv("cleaned_data003.csv").head(10)
# Out:
#    城市        名称   星级   评分  价格     销量       省/市/区                    坐标  \
# 0  上海  上海海昌海洋公园  4 A    0 NaN  19406  上海·上海·浦东新区  121.915647,30.917713
# 1  上海   上海野生动物园  5 A  3.6 NaN   6764  上海·上海·浦东新区  121.728112,31.059636
# 2  上海      东方绿舟  4 A  3.5 NaN   5353   上海·上海·青浦区  121.015977,31.107866
# 3  上海      东方明珠  5 A  3.8 NaN   3966  上海·上海·浦东新区   121.50626,31.245369
# 4  上海  上海佛罗伦萨小镇   3A    0 NaN   2682  上海·上海·浦东新区  121.770767,31.202718
# 5  上海     上海科技馆  5 A  3.7 NaN   2120  上海·上海·浦东新区   121.54785,31.224219
# 6  上海        豫园  4 A  4.2 NaN   2103   上海·上海·黄浦区  121.498971,31.233463
# 7  上海     上海动物园  4 A  3.6 NaN   1718   上海·上海·长宁区  121.369411,31.199264
# 8  上海  东平国家森林公园  4 A  3.5 NaN    836   上海·上海·崇明岛  121.487554,31.689225
# 9  上海    上海影视乐园  4 A  3.5 NaN    830   上海·上海·松江区  121.319396,31.016693
#
#                                                   简介   是否免费  \
# 0                                 看珍稀海洋生物 | 玩超刺激娱乐项目  False
# 1                                全球动物聚集地 | 零距离和动物做朋友  False
# ...
